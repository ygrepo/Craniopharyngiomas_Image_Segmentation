# %%
import pandas as pd
from pathlib import Path
import numpy as np 
import matplotlib.pyplot as plt
from scipy import stats
import sys
sys.path.insert(0, "..")   
from src.plot_util import plot_binary_lasso_cv_metrics, plot_multinomial_lasso_cv_metrics

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
path = "../output/metrics/preop_binary_l1_lasso_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C  mean_auc  std_auc  ci_auc_lower_95  ci_auc_upper_95  p_auc_vs_0_5  \
# 0  0.0001      0.50  0.00000              NaN              NaN           NaN
# 1  0.0010      0.50  0.00000              NaN              NaN           NaN
# 2  0.0100      0.50  0.00000              NaN              NaN           NaN
# 3  0.1000      0.50  0.00000              NaN              NaN           NaN
# 4  1.0000      0.53  0.25219         0.308945         0.751055      0.790241
#
#     mean_f1    std_f1  mean_f1_baseline  std_f1_baseline  \
# 0  0.551648  0.278471          0.571429         0.285714
# 1  0.285714  0.349927          0.571429         0.285714
# 2  0.551648  0.278471          0.571429         0.285714
# 3  0.551648  0.278471          0.571429         0.285714
# 4  0.548701  0.192037          0.571429         0.285714
#
#    mean_f1_diff_vs_baseline  std_f1_diff_vs_baseline  p_f1_vs_baseline  \
# 0                 -0.019780                 0.421176          0.916364
# ...

# %%
df.columns
# Out:
# Index(['C', 'mean_auc', 'std_auc', 'ci_auc_lower_95', 'ci_auc_upper_95',
#        'p_auc_vs_0_5', 'mean_f1', 'std_f1', 'mean_f1_baseline',
#        'std_f1_baseline', 'mean_f1_diff_vs_baseline',
#        'std_f1_diff_vs_baseline', 'p_f1_vs_baseline', 'is_best'],
#       dtype='object')

# %%
path = "../output/figures/preop_binary_l1_lasso_cv_metrics.tiff"
plot_binary_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_multinomial_l1_lasso_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C  mean_auc_macro  std_auc_macro  ci_auc_macro_lower_95  \
# 0  0.0001        0.500000       0.000000                    NaN
# 1  0.0010        0.500000       0.000000                    NaN
# 2  0.0100        0.500000       0.000000                    NaN
# 3  0.1000        0.467249       0.065503               0.409833
# 4  1.0000        0.402116       0.078506               0.333303
#
#    ci_auc_macro_upper_95  p_auc_macro_vs_0_5  mean_f1_macro  std_f1_macro  \
# 0                    NaN                 NaN       0.148645      0.070650
# 1                    NaN                 NaN       0.086667      0.040000
# 2                    NaN                 NaN       0.140952      0.066024
# 3               0.524664            0.263552       0.180794      0.063210
# 4               0.470930            0.005303       0.236740      0.117722
#
#    mean_f1_macro_baseline  std_f1_macro_baseline  \
# 0                0.231502               0.013187
# ...

# %%
path = "../output/figures/preop_multinomial_l1_lasso_cv_metrics.tiff"
plot_multinomial_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_binary_l2_ridge_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C penalty  l1_ratio  mean_auc   std_auc  ci_auc_lower_95  \
# 0  0.0001      l2       NaN      0.61  0.174356         0.457170
# 1  0.0010      l2       NaN      0.65  0.151658         0.517066
# 2  0.0100      l2       NaN      0.62  0.180555         0.461737
# 3  0.1000      l2       NaN      0.64  0.222261         0.445180
# 4  1.0000      l2       NaN      0.59  0.203470         0.411651
#
#    ci_auc_upper_95  p_auc_vs_0_5   mean_f1    std_f1  mean_f1_baseline  \
# 0         0.762830      0.158327  0.564286  0.161414          0.571429
# 1         0.782934      0.026992  0.590952  0.185362          0.571429
# 2         0.778263      0.137244  0.672424  0.093481          0.571429
# 3         0.834820      0.158990  0.623232  0.171439          0.571429
# 4         0.768349      0.322629  0.615801  0.140413          0.571429
#
#    std_f1_baseline  mean_f1_diff_vs_baseline  std_f1_diff_vs_baseline  \
# 0         0.285714                 -0.007143                 0.331252
# ...

# %%
path = "../output/figures/preop_binary_l2_ridge_cv_metrics.tiff"
plot_binary_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_binary_elasticnet_l1ratio_0.5_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C     penalty  l1_ratio  mean_auc   std_auc  ci_auc_lower_95  \
# 0  0.0001  elasticnet       0.5      0.50  0.000000              NaN
# 1  0.0010  elasticnet       0.5      0.50  0.000000              NaN
# 2  0.0100  elasticnet       0.5      0.50  0.000000              NaN
# 3  0.1000  elasticnet       0.5      0.63  0.143527         0.504193
# 4  1.0000  elasticnet       0.5      0.58  0.278568         0.335825
#
#    ci_auc_upper_95  p_auc_vs_0_5   mean_f1    std_f1  mean_f1_baseline  \
# 0              NaN           NaN  0.551648  0.278471          0.571429
# 1              NaN           NaN  0.285714  0.349927          0.571429
# 2              NaN           NaN  0.428571  0.349927          0.571429
# 3         0.755807      0.042834  0.645758  0.069131          0.571429
# 4         0.824175      0.520768  0.609307  0.205819          0.571429
#
#    std_f1_baseline  mean_f1_diff_vs_baseline  std_f1_diff_vs_baseline  \
# ...

# %%
path = "../output/figures/preop_binary_elasticnet_l1ratio_0.5_cv_metrics.tiff"
plot_binary_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_multinomial_l2_ridge_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C penalty  l1_ratio  mean_auc_macro  std_auc_macro  \
# 0  0.0001      l2       NaN        0.441640       0.133269
# 1  0.0010      l2       NaN        0.447011       0.130706
# 2  0.0100      l2       NaN        0.492910       0.058783
# 3  0.1000      l2       NaN        0.480661       0.067497
# 4  1.0000      l2       NaN        0.456217       0.069085
#
#    ci_auc_macro_lower_95  ci_auc_macro_upper_95  p_auc_macro_vs_0_5  \
# 0               0.324825               0.558456            0.327483
# 1               0.332442               0.561579            0.364659
# 2               0.441384               0.544436            0.787394
# 3               0.421498               0.539825            0.521743
# 4               0.395661               0.516773            0.156448
#
#    mean_f1_macro  std_f1_macro  mean_f1_macro_baseline  std_f1_macro_baseline  \
# 0       0.222910      0.122516                0.231502               0.013187
# ...

# %%
path = "../output/figures/preop_multinomial_l2_ridge_cv_metrics.tiff"
plot_multinomial_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_multinomial_elasticnet_l1ratio_0.3_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C     penalty  l1_ratio  mean_auc_macro  std_auc_macro  \
# 0  0.0001  elasticnet       0.3        0.500000       0.000000
# 1  0.0010  elasticnet       0.3        0.500000       0.000000
# 2  0.0100  elasticnet       0.3        0.500000       0.000000
# 3  0.1000  elasticnet       0.3        0.399524       0.045019
# 4  1.0000  elasticnet       0.3        0.405820       0.046293
#
#    ci_auc_macro_lower_95  ci_auc_macro_upper_95  p_auc_macro_vs_0_5  \
# 0                    NaN                    NaN                 NaN
# 1                    NaN                    NaN                 NaN
# 2                    NaN                    NaN                 NaN
# 3               0.360063               0.438985        6.019930e-07
# 4               0.365243               0.446398        5.386868e-06
#
#    mean_f1_macro  std_f1_macro  mean_f1_macro_baseline  std_f1_macro_baseline  \
# 0       0.180952      0.028571                0.231502               0.013187
# ...

# %%
path = "../output/figures/preop_multinomial_elasticnet_l1ratio_0.3_cv_metrics.tiff"
plot_multinomial_lasso_cv_metrics(df, fn=Path(path))

# %%
path = "../output/metrics/preop_binary_l2_ridge_top60_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C penalty  l1_ratio  mean_auc   std_auc  ci_auc_lower_95  \
# 0  0.0001      l2       NaN      0.80  0.130384         0.685713
# 1  0.0010      l2       NaN      0.80  0.130384         0.685713
# 2  0.0100      l2       NaN      0.80  0.130384         0.685713
# 3  0.1000      l2       NaN      0.82  0.136382         0.700456
# 4  1.0000      l2       NaN      0.81  0.135647         0.691101
#
#    ci_auc_upper_95  p_auc_vs_0_5   mean_f1    std_f1  mean_f1_baseline  \
# 0         0.914287  2.675813e-07  0.688961  0.217316          0.571429
# 1         0.914287  2.675813e-07  0.842424  0.124796          0.571429
# 2         0.914287  2.675813e-07  0.842424  0.124796          0.571429
# 3         0.939544  1.549262e-07  0.795152  0.148028          0.571429
# 4         0.928899  3.218202e-07  0.780202  0.160320          0.571429
#
#    std_f1_baseline  mean_f1_diff_vs_baseline  std_f1_diff_vs_baseline  \
# 0         0.285714                  0.117532                 0.349984
# ...

# %%
path = "../output/figures/preop_binary_l2_ridge_top60_cv_metrics.tiff"
plot_binary_lasso_cv_metrics(df, 
                             title="Preop Binary Model (Top 60 Features): 5-fold CV Results", 
                             title_fontsize=14, 
                             title_fontweight="bold",
                             fn=Path(path))

# %%
path = "../output/metrics/preop_multinomial_elasticnet_l1ratio_0.3_top40_cv_metrics.csv"
df = pd.read_csv(path)
df.head()
# Out:
#         C     penalty  l1_ratio  mean_auc_macro  std_auc_macro  \
# 0  0.0001  elasticnet       0.3         0.50000       0.000000
# 1  0.0010  elasticnet       0.3         0.50000       0.000000
# 2  0.0100  elasticnet       0.3         0.50000       0.000000
# 3  0.1000  elasticnet       0.3         0.65127       0.177298
# 4  1.0000  elasticnet       0.3         0.78455       0.155575
#
#    ci_auc_macro_lower_95  ci_auc_macro_upper_95  p_auc_macro_vs_0_5  \
# 0                    NaN                    NaN                 NaN
# 1                    NaN                    NaN                 NaN
# 2                    NaN                    NaN                 NaN
# 3               0.495862               0.806678            0.056416
# 4               0.648183               0.920918            0.000043
#
#    mean_f1_macro  std_f1_macro  mean_f1_macro_baseline  std_f1_macro_baseline  \
# 0       0.148645      0.070650                0.231502               0.013187
# ...

# %%
path = "../output/figures/preop_multinomial_elasticnet_l1ratio_0.3_top40_cv_metrics.tiff"
plot_multinomial_lasso_cv_metrics(df, title="Preop Multinomial Model (Top 40 Features): 5-fold CV Results", 
                                  fn=Path(path))
